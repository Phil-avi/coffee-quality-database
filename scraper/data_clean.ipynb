# %% [markdown]
# # Clean Scrapped Data

# %%
import pandas as pd
import numpy as np
import re
import os
pd.set_option('display.max_columns',50)

# %%
ls
# Out:
# arabica_data_cleaned.csv  data_clean.ipynb          scrapped_files_arabica/
# arabica_final.csv         robusta_data_cleaned.csv  scrapped_files_robusta/
# arabica_new.csv           robusta_new.csv
# arabica_ratings_raw.csv   robusta_ratings_raw.csv

# %%
a_new=pd.read_csv('arabica_new.csv')
a_old=pd.read_csv('arabica_data_cleaned.csv',index_col=False)

# %% [markdown]
# ## Clean newly scrapped data

# %%
# Create new cols and rename cols
a_new['Species']='Arabica'
a_new['Cupper.Points']=np.nan
a_new=a_new.rename(columns={'Country of Origin':'Country.of.Origin','Farm Name':'Farm.Name','Lot Number':'Lot.Number','ICO Number':'ICO.Number','Number of Bags':'Number.of.Bags','Bag Weight':'Bag.Weight','In-Country Partner':'In.Country.Partner','Harvest Year':'Harvest.Year','Grading Date':'Grading.Date','Processing Method':'Processing.Method','Clean Cup':'Clean.Cup','Total Cup Points':'Total.Cup.Points','Category One Defects':'Category.One.Defects','Category Two Defects':'Category.Two.Defects','Certification Body':'Certification.Body','Certification Address':'Certification.Address','Certification Contact':'Certification.Contact'})

# %%
# Reorder cols and change col data types
a_new=a_new[['Species','Owner','Country.of.Origin','Farm.Name','Lot.Number','Mill','ICO.Number','Company','Altitude','Region','Producer','Number.of.Bags','Bag.Weight','In.Country.Partner','Harvest.Year','Grading.Date','Owner.1','Variety','Processing.Method','Aroma','Flavor','Aftertaste','Acidity','Body','Balance','Uniformity','Clean.Cup','Sweetness','Cupper.Points','Total.Cup.Points','Moisture','Category.One.Defects','Quakers','Color','Category.Two.Defects','Expiration','Certification.Body','Certification.Address','Certification.Contact']]
a_new['Moisture']=a_new['Moisture'].str.rstrip('%')
a_new['Moisture']=a_new['Moisture'].apply(lambda s: float(s))*0.01
a_new['Category.One.Defects']=a_new['Category.One.Defects'].apply(lambda s: int(s.split()[0]))
a_new['Category.Two.Defects']=a_new['Category.Two.Defects'].apply(lambda s: int(s.split()[0]))
a_new['Quakers']=a_new.Quakers.astype('float')

# %% [markdown]
# ## Clean old dataset

# %%
# Del unwanted cols
a_old['Altitude']=a_old['altitude_mean_meters']
a_old=a_old.drop(['Unnamed: 0','unit_of_measurement','altitude_low_meters','altitude_high_meters','altitude_mean_meters'],1)

# %% [markdown]
# ## Combine Datasets

# %%
# Check the shape of datasets
print(f'The shape of newly scraped dataset is: {a_new.shape}')
print(f'The shape of previous` dataset is: {a_old.shape}')
# Out:
# The shape of newly scraped dataset is: (128, 39)
# The shape of previous` dataset is: (1311, 39)

# %%
a_final=pd.concat([a_new,a_old],axis=0)
print(f'The shape of final dataset is: {a_final.shape}')
# Out:
# The shape of final dataset is: (1439, 39)

# %% [markdown]
# ### Sort unique values to look for misspellings

# %%
# Transform cols values into lower case
a_final['Owner']=a_final.Owner.str.lower()
a_final['Country.of.Origin']=a_final['Country.of.Origin'].str.lower()
a_final['Farm.Name']=a_final['Farm.Name'].str.lower()
a_final['Mill']=a_final['Mill'].str.lower()
a_final['Company']=a_final['Company'].str.lower()
a_final['Region']=a_final['Region'].str.lower()
a_final['Producer']=a_final['Producer'].str.lower()

# %%
# Check owner col
a_final['Owner']=a_final['Owner'].apply(lambda s: str(s))
sorted(a_final.Owner.unique())
# Out:
# ['acacia hills ltd',
#  'adam ciruli ye',
#  'adam kline',
#  'adriana torres rico quevedo',
#  'afca',
#  'al-impex business plc',
#  'alejandro garcia palacios',
#  'alexandra katona-carroll',
#  'alexis rodriguez',
#  'alfredo bojalil',
#  'almacafe',
#  'alvaro quiros perez',
#  'amanda powers',
#  'amkeni gourmet coffee group',
#  'ana gonzales',
#  'andrea bernal',
#  'andreas kussmaul',
#  'andres martinez leon',
#  'andrew bowman',
#  'andry simarmata',
#  'angel oscar medina rodriguez',
#  'angelica paola citan lopez',
#  'armando luis pohlenz martinez',
#  'artemio zapata tejeda',
#  'asefa dukamo keroma',
#  'asociación aldea global jinotega',
#  'assefa belay coffee producer',
#  'atlantic specialty coffee',
#  'aulia arif syahri',
#  'balam hinyula',
#  'balbino ramirez flores',
#  'bencafe, s. a.',
#  'beneficio santa rosa',
#  'benjamin schmerler',
#  'bismarck castro',
#  'blossom valley international',
#  'bob mccauley',
#  'bourbon specialty coffees',
#  'bourbon specialty coffees sa',
#  'brayan cunha souza',
#  'brent hall',
#  'brian beck',
#  'brian speckman',
#  'bugestal sprl',
#  'bugisu cooperative union',
#  'bulamburi coffee farmers association',
#  'burka coffee estate',
#  'byron gonzalez',
#  'cadexsa',
#  'cafe de don balbino s.c. de r.l. de c.v.',
#  'cafe politico',
#  'cafebras',
#  'cafes finos de exportacion s de r.l.',
#  'cafes tomari sa de cv',
#  'cafetalera internacional cafinter, s.a.',
#  'calixto guillen vazquez',
#  'carcafe ltda ci',
#  'carl walker',
#  'case noyale ltd',
#  'ceca, s.a.',
#  'chris finch',
#  'christina dusing',
#  'coffee export',
#  'coffeebythebag.com , inc',
#  'colbran coffeelands, ltd.',
#  'comercial internacional exportadora, s.a.',
#  'compañia colombiana agroindustrial s.a',
#  'compañia hondureña del cafe s.a de c.v.',
#  'consejo salvadoreño del café',
#  'cooperativa el gorrion r.l',
#  'cosecha bienestar sapi de cv',
#  'cqi q coffee sample representative',
#  'cqi taiwan icp cqi台灣合作夥伴',
#  'dae ltd company',
#  'damari absalome',
#  'damaso martinez perez',
#  'dane loraas',
#  'daniel friedlander',
#  'daniel magu',
#  'dario cesar galeana sanchez',
#  'debesa agro industry plc',
#  'delfina leon shine',
#  'diamond enterprise plc',
#  'didas',
#  'diego manuel woolrich ramirez',
#  'doi chaang coffee company',
#  'doi tung development project',
#  'dr. marcel lorenz',
#  'dream together',
#  'ecom japan limited',
#  'ed&f man volcafe brasil ltda.',
#  'eduardo luis augusto velazquez solis',
#  'edwin agasso',
#  'eileen koyanagi',
#  'ekai international company ltd.',
#  'el equimite, cafetal biodinámico',
#  'elsy reyes',
#  'enrique eduardo lopez aguilar',
#  'enrique mitre lopez',
#  'eric jesus cordoba arroyo',
#  'eric thormaehlen',
#  'eric wu',
#  'ernesto rodriguez luna',
#  'essencecoffee',
#  'ethiopia commodity exchange',
#  'eugene holman pew',
#  'expocaccer coop dos cafeic do cerrado ltda',
#  'exportadora atlantic, s.a.',
#  'exportadora de cafe condor s.a',
#  'fabian calderon mora',
#  'fang, cheng lun 方政倫',
#  'federacion nacional de cafeteros',
#  'federación nacional de cafeteros - logística comercial',
#  'federico pacheco perez',
#  'felipe isaza',
#  'fernando',
#  'fernando mendoza aparicio',
#  'filemon mendoza campos',
#  'finca estate',
#  'finca las nieves',
#  'francisco a mena',
#  'francisco hernandez lorenzo',
#  'francisco ruiz nunez',
#  'fredy gordillo reyes',
#  'gabriel barbara',
#  'gabriel bernardo rivas ross',
#  'garet alban',
#  'genius coffee',
#  'george a. fernandez',
#  'gerardo hernandez valderrabano',
#  'german negron',
#  'gladness obed pallangyo',
#  'gloria antonieta escobar urrutia',
#  'gonzalo de aquino flores',
#  'gonzalo hernandez',
#  'great lakes coffee uganda',
#  'gregorio sebba',
#  'grounds for health admin',
#  'grupo cafetalero los brujos spr de rl',
#  'grupo juvenil magtayani, ac',
#  'grupo santab s.a de c.v.',
#  'guillermo eduardo bobadilla muguira',
#  'guillermo rojas saldana',
#  'gustavo abarca solis',
#  'gustavo amieva gonzalez',
#  'hector gabriel barreda nader',
#  'hider abamecha',
#  'homero antonio de anda andrade',
#  'honor dela fuente',
#  'hsu ting yey許定燁',
#  'hugo valdivia',
#  'ibero coffee trading co (t) ltd',
#  'ibero kenya limited',
#  'ibrahim hussien speciality coffee producer &export',
#  'ikuto uehara',
#  'immaculata john',
#  'ipanema coffees',
#  'irene alves santos',
#  'israel eduardo paz garcia',
#  'itdp international',
#  'itiah coffee llc',
#  'itochu corporation',
#  'j.andrade',
#  'jack parker',
#  'jacques pereira carneiro',
#  'janny marlith torres',
#  'jesus carlos cadena valdivia',
#  'jesus carlos cardenas valdivia',
#  'jesus salazar velasco',
#  'ji-ae ahn',
#  'jim郭志豪',
#  'joao paulo bueno sanches',
#  'jorge francisco martinez hachity',
#  'jorge octavio escamilla prado',
#  'jose armando norberto borzani lemini',
#  'jose daniel cobilt castro',
#  'jose luis munoz guerrero',
#  'jose manuel vergara cortes',
#  'joshua marsceau',
#  'josé luis rojas yeo',
#  'joão batista jarduli',
#  'juan avenamar rodriguez funez',
#  'juan carlos garcia lopez',
#  'juan garcia hernandez',
#  'juan hermilio sampieri carcamo',
#  'juan luis alvarado romero',
#  'juan luis ortega carballo',
#  'juan manuel sanchez silvestre',
#  'juana rodriguez gutierrez',
#  'julio cesar robles flores',
#  'julio perez hernandez',
#  'jungle estate',
#  'kabum trading company',
#  'kao ming lee',
#  'karatu estate',
#  'kavita vohora',
#  'kawacom uganda ltd',
#  'kennedy macharia',
#  'kerchanshe',
#  'klem organics',
#  'kona pacific farmers cooperative',
#  'kongoni estate',
#  'kurt kappeli',
#  'kyagalanyi coffee ltd',
#  'kyagalanyi ltd',
#  'langiro farm group',
#  'leonides de la cruz lopez',
#  'lin, che-hao krude 林哲豪',
#  'loic rwagasana',
#  'luis roberto fermoso beltran',
#  'lusso lab',
#  'lydiah mwangi',
#  'mandalay coffee group',
#  'manuel herrera juarez',
#  'mao-heng chu',
#  'marco tulio fuentes lobo',
#  'marco virgilio ramirez teliz',
#  'maria amalia guadalupe toriello elorza',
#  'maria de la paz aguilar guillen',
#  'maria guadalupe gomez anzo',
#  'maria imelda uscanga martinez',
#  'maria luisa del carmen rojas narvaez',
#  'mario jose fernandez',
#  'martin jimenez casiano',
#  'masamichi hiroike',
#  'max gurdian',
#  'mayra yessenia torres',
#  'mcomafa co ltd',
#  'mdh',
#  'metad plc',
#  'michael gavina',
#  'miguel cortes moreno',
#  'min hlaing',
#  'minwook ku',
#  'mlimani ngarashi',
#  'modesto landeros flores',
#  'mohammed lalo',
#  'montegrande',
#  'mr.brown cafe',
#  'myriam kaplan-pasternak',
#  'myrna roxana galvez gonzalez',
#  'nan',
#  'nestor mendez gomez',
#  'ngila estate ltd',
#  'ngorogoro convenant estate',
#  'ngu shwe li',
#  'nile highland arabica coffee farmers',
#  'nitin coffee estate',
#  'nomura trading co., ltd.',
#  'nora zeas',
#  'nucoffee',
#  'nyapea coffee farmers association',
#  'obed rendon ponce',
#  'octavio augusto diaz trejo',
#  'olam agro colombia',
#  'olivia hernandez virves',
#  'organizaciones de productores de cafe colimense',
#  'oscar ortega carballo',
#  'owen carver',
#  'pablo cervantes morelos        ',
#  'pablo enrique martinez gama',
#  'pedro santos e silva',
#  'philip schluter',
#  'productores de especialidad emiliano zapeata, spr.',
#  'productos y servicios chilindron s.a. de c.v.',
#  'pt.royal pacific indah international',
#  'ptraas',
#  'racafe & cia s.c.a',
#  'rachel peterson',
#  'rashid moledina & co. (msa) ltd.',
#  'raúl vargas',
#  'renee a. perrine',
#  'ricardo aaron sampieri marini',
#  'rob stephen',
#  'rob tuttle',
#  'roberto licona franco',
#  'rodrigo amaya',
#  'rodrigo soto',
#  'rolando lacayo',
#  'romulo bello flores',
#  'rosa aurora falcon fernandez',
#  'rosario miguel hernandez',
#  'royal base corporation',
#  'rre kunene',
#  'ruddy azofeifa',
#  'salvador caro carrion',
#  'samuel eli gurel',
#  'samuel muhirwa',
#  'sanjava coffee',
#  'santa laura exportadora de cafe s.l.e.c. s.a.',
#  'santiago solis ayerdi',
#  'sarawut premjit',
#  'saul m. hernandez ramirez',
#  'seid damtew coffee planataion',
#  'selian coffee estate',
#  'semiramis casas velazquez',
#  'sergio de la vequia bernardi',
#  'sergio landa alarcon',
#  'shah plantations',
#  'shangrilla estate ltd',
#  'shwe yin mar coffee',
#  'simon mahinda',
#  'solomon worku',
#  'specialty coffee association of indonesia',
#  'specialty coffee-korea',
#  'star cafe ltd',
#  'stephany escamilla femat',
#  'steven kil',
#  'sucafina colombia sas',
#  'sunvirtue co., ltd.',
#  'sustainable harvest coffee',
#  'tadessa desta amene',
#  'takanori suzuki',
#  'taylor winch (coffee) ltd.',
#  'taylor winch (t) ltd',
#  'tembo coffee company ltd',
#  'the coffee source inc.',
#  'tomas edelmann blass',
#  'troy quimby',
#  'tutunze kahawa ltd',
#  'u htun htun',
#  'u mg mg',
#  'u soe',
#  'ucfa',
#  'veronica lopez castillejos',
#  'victor hugo melchor cordova',
#  'victoria',
#  'virginia gordillo gordillo',
#  'viridiana',
#  'volcafe japan',
#  'volcafe ltda. - brasil',
#  'wali ali',
#  'wayner jimenez',
#  'welson de lacerda barbosa',
#  'william ho',
#  'wilson gonzalez ramos',
#  'yasmin cofffee plantation plc',
#  'yidnekachew dabessa',
#  'young kim',
#  'yukinobu ueda',
#  'yunnan coffee exchange',
#  'zarah zamora perez',
#  '松澤宏樹 koju matsuzawa',
#  '郭亮志 guoliangzhi']

# %%
a_final['Owner']=a_final['Owner'].replace('bourbon specialty coffees sa','bourbon specialty coffees')
a_final['Owner']=a_final['Owner'].replace('federación nacional de cafeteros - logística comercial','federacion nacional de cafeteros')
a_final['Owner']=a_final['Owner'].replace('jesus carlos cadena valdivia','jesus carlos cardenas valdivia')
a_final['Owner']=a_final['Owner'].replace('taylor winch (t) ltd','taylor winch (coffee) ltd.')
a_final['Owner']=a_final['Owner'].replace('nan',np.nan)

# %%
# Check country col
a_final['Country.of.Origin']=a_final['Country.of.Origin'].apply(lambda s: str(s))
sorted(a_final['Country.of.Origin'].unique())
# Out:
# ['brazil',
#  'burundi',
#  'china',
#  'colombia',
#  'costa rica',
#  'cote d?ivoire',
#  'ecuador',
#  'el salvador',
#  'ethiopia',
#  'guatemala',
#  'haiti',
#  'honduras',
#  'india',
#  'indonesia',
#  'japan',
#  'kenya',
#  'laos',
#  'malawi',
#  'mauritius',
#  'mexico',
#  'myanmar',
#  'nan',
#  'nicaragua',
#  'panama',
#  'papua new guinea',
#  'peru',
#  'philippines',
#  'rwanda',
#  'taiwan',
#  'tanzania, united republic of',
#  'thailand',
#  'uganda',
#  'united states',
#  'united states (hawaii)',
#  'united states (puerto rico)',
#  'vietnam',
#  'zambia']

# %%
a_final['Country.of.Origin']=a_final['Country.of.Origin'].replace('nan',np.nan)

# %%
# Check farm col
a_final['Farm.Name']=a_final['Farm.Name'].apply(lambda s: str(s))
sorted(a_final['Farm.Name'].unique())
# Out:
# ['-',
#  '1',
#  '175 coffee',
#  '200 farms',
#  '2000 farmers',
#  '2000 farms',
#  'a shu she coffee 阿束社咖啡莊園',
#  'acacia hills',
#  'ada farm',
#  'agropecuaria quiagral',
#  'agua caliente',
#  'agua de la mariposa',
#  'aldea global',
#  "alicia's farm",
#  'alishan zou zhu yuan 阿里山鄒築園',
#  'alta luz',
#  'alto cafezal',
#  'amkeni',
#  'ampcg',
#  'ano family',
#  'aolme',
#  'apollo co., ltd.',
#  'apollo estate',
#  'aprocafi',
#  'arianna farms',
#  'aricha coop',
#  'arroyo triste, arroyo triste, san jose vista hermosa',
#  'arsyad, budi',
#  'asefa dukamo coffee plantation',
#  'asociación aldea global jinotega',
#  'asoperc',
#  'bacofa',
#  'bai he lin coffee 白鶴林咖啡莊園',
#  'baijiada coffee farm佰加達咖啡莊園',
#  'baishencun coffee farm百勝村咖啡莊園',
#  'baishengcun coffee 百勝村咖啡莊園',
#  'barra estate',
#  'barranca de las flores',
#  'beneficio el torreon',
#  'beneficio montañas del diamante',
#  'bethel',
#  'bi yun si shi yi 碧云四十一咖啡坊',
#  'blend',
#  'blue lake',
#  'bola de oro',
#  'bsr',
#  'buginyanya',
#  'bugisu shamba',
#  'bulago & buginyanya',
#  'bulamburi coffee farmers',
#  'burka coffee estate',
#  'burka coffee estates',
#  'cachoeira da grama',
#  'cachoeira da grama farm',
#  'cafebras comercio de cafes',
#  'cafebras comercio de cafes do brasil s/a',
#  'cafebras comercio de café',
#  'cafebrascomercio de café',
#  'cafebrascomercio de cafés',
#  'cafebrascomercio decafe',
#  'cafetal',
#  'cafetal el equimite, rancho agroecológico',
#  'cafetal santa maria',
#  'cafetal sinai',
#  'cafetalera aquiares',
#  'cafetales santa matilde',
#  'café citrus',
#  'café do paraíso',
#  'caltuchoco',
#  'campo das flores',
#  'canoa manzanillo',
#  'capoeirinha',
#  'carrillo cooperativa',
#  'casa blanca',
#  'cascajal farm',
#  'case noyale ltd',
#  'castelhana farm',
#  'caxambu',
#  'cañada fria',
#  'cerca de los angeles',
#  'cerro bueno',
#  'cerro negro',
#  'chang yu liang 張玉良',
#  'chapultepec',
#  'chebonet (23) women coffee',
#  'chen lin',
#  'chesiyo farmer group',
#  'chikali',
#  'chilcuatla',
#  'chimpumba',
#  'chinongo',
#  'chiquimulja / alpha cafe / senfro',
#  'cianorte',
#  'cipresal',
#  'club green',
#  'cluster beneficio santa rosa',
#  'cnra station of divo',
#  'co-op #12',
#  'cofradia',
#  'comonyaj noptic s de ss',
#  'comunidad de canoas',
#  'comunidad la yerbabuena',
#  'conquista / morito',
#  'consolapa',
#  'contact | sidacoop@ethionet.net',
#  'coop. hoja blanca - fedecocagua',
#  'coopellanobonito',
#  'coopetarrazú',
#  'copalita',
#  'corral del diablo lote 1',
#  'corta pico',
#  'cortapico',
#  'cre-leg l-4',
#  'cruz verde',
#  'darmawi',
#  'delfina farm',
#  'doe kwin',
#  'doi chaang coffee original co.,ltd',
#  'doi tung development project',
#  'dongshan gaoyuan village chief manor coffee tainan, taiwan 台灣台南東山高原村長莊園咖啡',
#  'dozen small farmer',
#  'dragon coffee 龍咖啡',
#  'dragon 龍咖啡',
#  'drima zede',
#  'ecc',
#  'echo coffee',
#  'ecobio colombia',
#  'el aguacate',
#  'el barbaro',
#  'el brigadum - la coronela',
#  'el carrizo',
#  'el centenario',
#  'el cerron',
#  'el chile',
#  'el delirio',
#  'el deseo',
#  'el desmoronado',
#  'el desmoronado, talpan de allende jalisco',
#  'el ejido',
#  'el encanto',
#  'el encinal',
#  'el faro',
#  'el filo',
#  'el guayabo',
#  'el injerto s.a.',
#  'el jabali',
#  'el limon',
#  'el limón',
#  'el majahual',
#  'el mirador',
#  'el morito',
#  'el nanchi',
#  'el naranjo',
#  'el nogal, la higuera, los laureles',
#  'el papaturro',
#  'el patalillo',
#  'el pino',
#  'el prado',
#  'el regadito',
#  'el regalito',
#  'el rodeo',
#  'el romance azul',
#  'el sacramento',
#  'el sauce',
#  'el suspiro',
#  'el tabaco',
#  'el tesoro',
#  'el vergel',
#  'el águila',
#  'elida estate',
#  'erussi farmers group',
#  'estate la patricia',
#  'exclusive coffees s.a.',
#  'exportadora café california',
#  'fahem coffee plantation',
#  'family farm',
#  'fazenda baipendi',
#  'fazenda bom jardim',
#  'fazenda cachoeira',
#  'fazenda capoeirnha',
#  'fazenda chamusca',
#  'fazenda do lobo',
#  'fazenda do sertao',
#  'fazenda grota funda',
#  'fazenda jericó',
#  'fazenda kaquend',
#  'fazenda pantano',
#  'fazenda recreio',
#  'fazenda rio brilhante',
#  'fazenda rio verde',
#  'fazenda sacramento',
#  'fazenda santo antonio',
#  'fazenda serra de três barras',
#  'fazenda serra negra',
#  'fazenda serrado',
#  'fazenda são josé mirante',
#  'fazenda são pedro',
#  'fazenda são sebastião',
#  'fazenda vista alegre',
#  'fazendas klem ltda',
#  'federación nacional de cafeteros de colombia',
#  'fiech (mixed producers)',
#  'finagro plantations ltd',
#  'finca apoxtla',
#  'finca aurora',
#  'finca beneficio el torreon',
#  'finca buenos aires',
#  'finca cafetalera la suiza',
#  'finca castillos',
#  'finca chanjul',
#  'finca cuetzalingo',
#  'finca custepec',
#  'finca el consuelo',
#  'finca el gavilancillo',
#  'finca el limon',
#  'finca el morito',
#  'finca el naranjal',
#  'finca el retiro',
#  'finca el trueno',
#  'finca estate',
#  'finca huehuetecpan',
#  'finca ixhuatlan',
#  'finca la chiripa',
#  'finca la costa',
#  'finca la esmeralda',
#  'finca la estancia',
#  'finca la fany',
#  'finca la fortuna',
#  'finca la joya',
#  'finca la orduña',
#  'finca las cuevitas',
#  'finca las marías',
#  'finca loma linda y anexo',
#  'finca los andes',
#  'finca los angeles',
#  'finca los barreales',
#  'finca los barreales 1112lban',
#  'finca los barreales 1112lbga7250412',
#  'finca los cerros y anexos',
#  'finca medina',
#  'finca monte azúl',
#  'finca monte grande',
#  'finca muxbal',
#  'finca nextlalpa',
#  'finca nueva linda',
#  'finca pluma hidalgo',
#  'finca quequesquez',
#  'finca salaca las brisas',
#  'finca san el retiro',
#  'finca san vicente',
#  'finca sant rosa',
#  'finca santa clara',
#  'finca santa teresa',
#  'finca sego',
#  'finca teocelo',
#  'finca tepictla',
#  'firemariyam hambela wamena deri',
#  'fln mirador',
#  'gabriel bernard rivas ross',
#  'gamboa',
#  'gao chun fang 高醇坊',
#  'genuine antigua medina',
#  'gicumbi',
#  'gisha',
#  'good mood coffee 馨晴咖啡        ',
#  'gran manzana y el aguacate',
#  'granja el sauce',
#  'grapos el porvenir',
#  'group bsc',
#  'grupo medina (pequeños productores)',
#  'guo cun nong yuan 國村農園',
#  'guo xin ka fei 國昕咖啡',
#  'guo xing ka fei wang 國姓咖啡王咖啡莊園',
#  'guoxing farm coffee 國姓農場咖啡        ',
#  'hacienda caracolillo',
#  'hacienda la esmeralda',
#  'hacienda san ignacio',
#  'haider abamecha coffee plantation',
#  'hamburgo 7 arroyos',
#  'hani',
#  'hasambo amcos',
#  'helena',
#  'heng lu coffee 橫鹿咖啡',
#  'hezya',
#  'honey drip',
#  'huanacaxtle',
#  'hula daddy kona coffee',
#  'ibanda farmers group',
#  'ibiraci regional',
#  'ijen highland, east java',
#  'ilomba 1',
#  'ilomba 2',
#  'imena cws',
#  'inoi',
#  'irisan, baguio',
#  'isule farmers group',
#  'jacksom mwasenga',
#  "jacob's estate 雅谷咖啡",
#  'jamaica',
#  'jia jia coffee 佳佳咖啡莊',
#  'jing jing café 晶晶坊青山咖啡教室',
#  'juan damaso',
#  'juliana',
#  'jungle estate',
#  'ka-vulungan coffee estate',
#  'kaasayi',
#  'kabeywa county',
#  'kachere',
#  'kakoma',
#  'kalugmanan agri development corp.',
#  'kampung keling, jumaraj, gurusinga, gongsol',
#  'kan tou mountain coffee 崁頭山咖啡館',
#  'kangunu',
#  'kapchorwa',
#  'kaptanya',
#  'karatina',
#  'karatu estate',
#  'kassandra',
#  'kata muduga',
#  'kavuzi',
#  'kawacom sipi project',
#  'kawacom uganda ltd sipi farmers group',
#  'kerchanshe',
#  'kianjavi',
#  'kigwandi',
#  'kona farms',
#  'kona pacific farmers cooperative',
#  'kongoni estate',
#  'la barranca',
#  'la bendicion',
#  'la berlina estate',
#  'la burbuja',
#  'la calera, barranca de la leona, el nogal',
#  'la canada',
#  'la castellana',
#  'la ceiba',
#  'la chaparral',
#  'la corralera',
#  'la cruz',
#  'la cuchilla',
#  'la cuesta',
#  'la curva',
#  'la distancia',
#  'la esmeralda',
#  'la esperanza',
#  'la esperanza y anexos',
#  'la esperanza, margarita nuyes',
#  'la gloria',
#  'la guama',
#  'la herradura',
#  'la igualdad',
#  'la joya',
#  'la lagunilla',
#  'la laja',
#  'la loma',
#  'la marina-el orizabeño',
#  'la montaña',
#  'la morena',
#  'la orduña',
#  'la orduña, coatepec, veracruz',
#  'la pagua',
#  'la pandora',
#  'la patrona, el trebol, la cadena',
#  'la primavera',
#  'la tejeria',
#  'la timbuchera; el ocotito y la hortaliza',
#  'la union monte verde',
#  'la victoria pante nubes',
#  'la vuelta',
#  'langiro farm group',
#  'las cebollas y anexos',
#  'las ceibas',
#  'las cuchillas',
#  'las delicias',
#  'las lomas',
#  'las merceditas',
#  'las minas',
#  'las moras',
#  'las nubes',
#  'las nubes - pante don jaime',
#  'las palmas',
#  'las promesas de san blass',
#  'las rosas',
#  'las truchas',
#  'leticia farm',
#  'linda vista',
#  'lintong nihuta',
#  'llano hermoso',
#  'local farm',
#  'local farmer',
#  'lomi tasha',
#  'los barreales 1112lbcat_s110312',
#  'los barreales 1112lbgr7230412',
#  'los brujos',
#  'los cedros',
#  'los charcos',
#  'los encinos',
#  'los girasoles',
#  'los guacharos various',
#  'los hicaques',
#  'los llanitos',
#  'los magueyes',
#  'los mesones',
#  'los pinos',
#  'los saltarines',
#  'lubanda amcos',
#  'm10',
#  'machure estate',
#  'makoka valley estate',
#  'mamsera',
#  'man ganna estate',
#  'mandalay coffee group',
#  'maria isabel',
#  'marre blanche',
#  'mata larga',
#  'matsuzawa coffee',
#  'mcomafa farm no1155gr',
#  'menglian ban’an coffee processing factory',
#  'menglian county nayun town mangzhang coffee farm',
#  'menglian gao sanlin coffee factory',
#  'menglian mang pan professional cooperative',
#  'mercon coffee group cisa',
#  'metad plc',
#  'mirador',
#  'mixed',
#  'mondul coffee estate',
#  'monterrey',
#  'moplaco',
#  'mount elgon area',
#  'msese',
#  'mt.elgon bugisu shamba 2',
#  'mt.elgon sipi falls cheema',
#  'mu he zi coffee 木盒子咖啡園',
#  'mubuyu munali',
#  'mudar',
#  'multiple',
#  'mus, eman',
#  'mviwambi coffee farmers',
#  'mwalyego amcos',
#  'myaing',
#  'myanganyanga',
#  'nan',
#  'naranjal',
#  'ngila estate',
#  'ngima',
#  'ngorogoro convenant estate',
#  'nguruma',
#  'nitin',
#  'non',
#  'none',
#  'not specificated',
#  'nueva granada',
#  'nueva linda',
#  'nyapea coffee farmers',
#  'ojo de agua',
#  "olhos d'agua",
#  'olotlan, el plan, criollo garnica',
#  'omicuatla',
#  'palantla',
#  'pancoer angkrek',
#  'pantano',
#  'pante carajillo',
#  'pante san pedro',
#  'pereira estate coffee',
#  'peña campana',
#  'peña negra',
#  'phone number | 0911-51-08-01, email | at',
#  'phone number | 0911-513824 email: gmt.ft',
#  'piamonte',
#  'pico del oro',
#  'pinzoneno',
#  'pitalito',
#  'platanal',
#  'pondokbaru, benermeriah',
#  'predio cañada del encino',
#  'producer group (approx. 1,000 farmers)',
#  'productor independiente guadalupe victoria',
#  'providencia',
#  "pu'er city longke coffee co.ltd",
#  "pu'er lingdu yunlin coffee co.ltd",
#  'puer jiangcheng fuwang coffee biotechnology co., ltd',
#  'pu’er specialty coffee cupping center',
#  'rancho bonito',
#  'rancho los laureles',
#  'rancho san francisco iii',
#  'rancho vigia',
#  'rio jorco',
#  'rio verde',
#  'rumukia farmers',
#  'rural cooperative society',
#  'sacún palma',
#  'san diego buena vista',
#  'san fernando, chiapas',
#  'san jose del lago',
#  'san josé y el portillo',
#  'san lorenzo',
#  'san marcos barrancas "san cristobal cuch',
#  'santa alina',
#  'santa bárbara',
#  'santa cecilia',
#  'santa clara, california y camila',
#  'santa cruz - pante don jaime',
#  'santa cruz - pante don manuel',
#  'santa cruz - pante doña graciela',
#  'santa fé 2',
#  'santa josefita',
#  'santa laura',
#  'santa maria',
#  'santa maria temaxcalapa',
#  'santa mariana',
#  'santa mariana/são vicente',
#  'santa martha',
#  'santa matilde',
#  'santa rosa',
#  'santa teresa',
#  'santo tomas pachuj',
#  'savan coffee bean',
#  'saveg coffee farm',
#  'seid damtew coffee planation',
#  'selian coffee estate',
#  'selva negra',
#  'sertao',
#  'sertao farm',
#  'several',
#  'several farmers',
#  'several farms',
#  'several, bukidnon, mindanao, philippines',
#  'shah plantation',
#  'shangrilla estate',
#  'sheng he shang pin coffee 聖荷上品咖啡坊',
#  'shi fang yuan 十方源',
#  'sierra madre',
#  'sierra nevada',
#  'sipi organic coffee project',
#  'sithar coffee farm',
#  'sitio claro',
#  'sitío corrego da olaria/são caetano',
#  'sitío santa luzia',
#  'sitío são geraldo',
#  'small holders farmer',
#  'sogestal kayanza',
#  'solomon worku',
#  'song yue coffee 嵩岳咖啡',
#  'sran temanggung plantation',
#  'su-zhen huang 黃素真',
#  'sucafina colombia sas',
#  'suma jkt itende',
#  'sunshine valley estate 向陽高山咖啡',
#  'supply chain ecom cca s.a.',
#  'são francisco da serra',
#  'são josé da lagoa',
#  'são rafael_ ra/ras certified',
#  'tairora cherry – bonta',
#  'taiwan hao ka 台灣好咖莊園',
#  'tega and tula special coffee farm',
#  'tepemalacax',
#  'tepetzingo',
#  'teresa',
#  'texpanco',
#  'thein kone',
#  'thiririka/maara',
#  'tlamatoca',
#  'tlapacoya',
#  'toarco jaya',
#  'tokoffee莊園',
#  'tomatlancillo',
#  'tres volcanes',
#  'tropica galliard',
#  'tsoustructive garden 鄒築園',
#  'tulla coffee farm',
#  'tuxpal',
#  'ucipa santa catarina',
#  'unex(guatemala)',
#  'union ramal santa cruz',
#  'unkown',
#  'usingini farm',
#  'utchisi mountain',
#  'valparaiso',
#  'various',
#  'various farms',
#  'vegas',
#  'very famous intl.名門義理國際股份有限公司',
#  'wat-ka-bu',
#  'waylead farms',
#  'weng hui ling 翁惠鈴',
#  'wu kun shan coffee 吳焜山咖啡園',
#  'xu yuan zhang 徐源漳',
#  'yara estate / benvar estate',
#  'yidnekachew dabessa coffee plantation',
#  'you siang coffee farmtainan, taiwan 台灣台南優香咖啡',
#  'yu jin gui 玉金櫃咖啡',
#  'yun lan coffee co. ltd',
#  'yunnan success trade co.ltd',
#  'yusrin',
#  'zapato de mico',
#  'zaragoza, montelibano, pamal navil',
#  'zenash',
#  'zhang li hong coffee 張立宏咖啡莊園',
#  'zhou wu mountain',
#  'zhuo wu shan coffee 卓武山咖啡農場',
#  'zou zhou yuan',
#  'água limpa',
#  '以勒咖啡',
#  '伊娜咖啡莊園',
#  '佐佑品咖啡莊園',
#  '優遊吧斯股份有限公司yuyupas international corp.',
#  '八杞莊園',
#  '十萬咖啡（shin wan café)',
#  '南投縣魚池鄉水社村中正路63-1號',
#  '台中市新社區崑山里',
#  '向陽台灣咖啡',
#  '大鋤花間 (hoe vs. flower coffee farm)',
#  '好自在咖啡莊園',
#  '山彎有機咖啡農場',
#  '崁頭山咖啡館 (kan tou mountain coffee)',
#  '嵩岳咖啡莊園',
#  '張文進莊園',
#  '御香咖啡園 (yuxiang coffee garden)',
#  '日月潭文武莊園',
#  '春風咖啡',
#  '林園咖啡 lin yuan coffee',
#  '王秋金',
#  '眉泉莊園        ',
#  '神谷山莊園',
#  '胖胖糖',
#  '谷泉咖啡莊園',
#  '鄉舍咖啡 hometown coffee',
#  '雅慕伊',
#  '馨晴咖啡 good mood coffee']

# %%
a_final['Farm.Name']=a_final['Farm.Name'].replace(['-','1','nan','non','none','not specificated','unkown'],np.nan)
a_final['Farm.Name']=a_final['Farm.Name'].replace(['various farms','several','several farmers','several farms'],'various')
a_final['Farm.Name']=a_final['Farm.Name'].replace(['cafebras comercio de cafes','cafebras comercio de cafes do brasil s/a','cafebrascomercio de café','cafebrascomercio de cafés','cafebrascomercio decafe',],'cafebras comercio de café')
a_final['Farm.Name']=a_final['Farm.Name'].replace('local farm','local farmer')
a_final['Farm.Name']=a_final['Farm.Name'].replace('2000 farmers','2000 farms')
a_final['Farm.Name']=a_final['Farm.Name'].replace('burka coffee estates','burka coffee estate')
a_final['Farm.Name']=a_final['Farm.Name'].replace('cachoeira da grama','cachoeira da grama farm')
a_final['Farm.Name']=a_final['Farm.Name'].replace('dragon 龍咖啡','dragon coffee 龍咖啡')
a_final['Farm.Name']=a_final['Farm.Name'].replace('el limon','el limón')
a_final['Farm.Name']=a_final['Farm.Name'].replace('el regadito','el regalito')
a_final['Farm.Name']=a_final['Farm.Name'].replace('zhou wu mountain','zhuo wu shan coffee 卓武山咖啡農場')

# %%
# Check mill col
a_final['Mill']=a_final['Mill'].apply(lambda s: str(s))
sorted(a_final['Mill'].unique())
# Out:
# ['1',
#  '17/18',
#  '175 coffee',
#  'a shu she coffee 阿束社咖啡莊園',
#  'ac la laja sa de cv',
#  'acacia hills ltd',
#  'acpa. ataisi de r.l.',
#  'ada farm',
#  'agrogora ltda',
#  'agroindustrias unidas de mexico',
#  'agua caliente',
#  'alcafe s.a. de c.v',
#  'aldea coffee',
#  'alfenas',
#  'algel de albino de corzo',
#  "alicia's farm",
#  'alishan zou zhu yuan 阿里山鄒築園',
#  'almacafé manizales - trilladora estación uribe',
#  'amkeni gourmet coffee group',
#  'amsa oaxaca',
#  'amsa tuxtla',
#  'angel albino corzo, chiapas',
#  'antioquia',
#  'apollo co., ltd.',
#  'apollo estate',
#  'aqua caliente, j.j. borja nathan. s.a',
#  'aricha coop',
#  'armazens gerais cocarive',
#  'arroyo triste, arroyo triste, san jose vista hermosa',
#  'arusha',
#  'arusha coffee mill ltd',
#  'aspinwall & co. ltd, mangalore',
#  'at site and addis ababa',
#  'atoyac de alvarez, guerrero',
#  'bachue',
#  'bachué',
#  'bai he lin coffee 白鶴林咖啡莊園',
#  'baijiada coffee farm佰加達咖啡莊園',
#  'baishengcun coffee 百勝村咖啡莊園',
#  'baroida',
#  'bcu',
#  'beneficio - finca aurora',
#  'beneficio 2000',
#  'beneficio atlantic condega',
#  'beneficio atlantic planta procedora condega',
#  'beneficio atlantic sebaco',
#  'beneficio cafetaleros del arrayanal',
#  'beneficio casa ruiz s.a.',
#  'beneficio central - efico',
#  'beneficio cuzcachapa',
#  'beneficio de cafetaleros el remudadero s.p.r. de r.l.',
#  'beneficio de café tecoxolco s. de r.l. de c.v.',
#  'beneficio dos puentes',
#  'beneficio el grande',
#  'beneficio el morito',
#  'beneficio exportacafe agua santa',
#  'beneficio humedo',
#  'beneficio ixchel',
#  'beneficio la igualdad',
#  'beneficio las brisas',
#  'beneficio las tres puertas',
#  'beneficio matagalpa coffee group, s.a.',
#  'beneficio montañas del diamante',
#  'beneficio nueva granada',
#  'beneficio palinsa',
#  'beneficio productores organicos de cnoas s.p.r. de r.l.',
#  'beneficio san carlos',
#  'beneficio san diego',
#  'beneficio san fernando',
#  'beneficio santa rosa',
#  'beneficio santa rosa s.a.',
#  'beneficio santo domingo - beneficio dosmil',
#  'beneficio seco de cafe de la soc. coop. tzotzilotic tzobolotic scl',
#  'beneficio serben',
#  'beneficio siembras vision (154)',
#  'beneficio soppexcca',
#  'beneficio valparaiso',
#  'bener meriah - gayo',
#  'bi yun si shi yi 碧云四十一咖啡坊',
#  'bogota',
#  'bogota - bachue',
#  'bon cafe s.a.',
#  'bonanza - armenia',
#  'bucaramanga',
#  'budeca',
#  'buenas vista, municipio de san bartolo tutotepec',
#  'bukonzo joint cfs',
#  'bulamburi coffee farmers',
#  'burka coffee estates',
#  'burka gudina',
#  'c.p.w.e',
#  'cadexsa',
#  'cafe altura de san ramon',
#  'cafe gourmet de sierra azul sc',
#  'cafeco 3',
#  'cafes de naranjal s.a. de c.v.',
#  'cafes finos de exportacion s. de r.l.',
#  'cafes tomari s.a de c.v.',
#  'cafes tomari sa de cv',
#  'cafetal el equimite, rancho agroecológico',
#  'cafetal la orduña',
#  'cafetal santa maria',
#  'cafetal sinai',
#  'cafetalera aquiares',
#  'cafetalera la cuchilla',
#  'cafetaleros de el remudadero s.p.r. de r.l.',
#  'cafetaleros de la yerbabuena spr de rl',
#  'cafex',
#  'cafico',
#  'café do paraíso',
#  'café don balbino',
#  'canoa manzanillo',
#  'carapina',
#  'carapina armazens gerais',
#  'cartago',
#  'catuai amarillo sss',
#  'cauca',
#  'central kenya coffee mills',
#  'chang yu liang 張玉良',
#  'cigrah',
#  'cigrah s.a de c.v.',
#  'cigrah sps',
#  'cisa / mercon',
#  'ckcm',
#  'ckcm mill',
#  'ckcm/nkg',
#  'club green',
#  'cnra station of divo',
#  'coatepec, ver',
#  'cocarive',
#  'coeb koperativ ekselsyo basen (350 members)',
#  'coffee business center',
#  'coffee business center (cbc) dry mill',
#  'coffee processing and warehouse enterpri',
#  'cohorsil',
#  'colonia baltazar r.leyva mancilla',
#  'comitla',
#  'comunidad de sacún palma, municipio de chilón, chiapas',
#  'comunidad la cumbre',
#  'concepcion',
#  'coocafe r.l',
#  'coop. hoja blanca - fedecocagua',
#  'coopacvod',
#  'coopeagri',
#  'cooperative agro-industrielle de marmela',
#  'coopetarrazú',
#  'copag',
#  'copag - varginha - mg',
#  'copag armazéns gerais ltda.',
#  'copag varginha',
#  'cordoba, ver.',
#  'coricafe sa',
#  'corral del diablo lote 1',
#  'corta pico balbino ramirez',
#  'cosautlan de carvajal, veracruz, méxico',
#  'cosecha bienestar sapi sa de cv',
#  'cre-leg beneficio',
#  'cruz verde',
#  'cuauhtemoc 321 col. trinidad de las huertas',
#  'dae ltd',
#  'desculpado, lavado y secado en secadoras solares',
#  'dinamo armazens gerais ltda',
#  'doi tung development project',
#  'dongshan gaoyuan village chief manor coffee tainan, taiwan 台灣台南東山高原村長莊園咖啡',
#  'dos puentes de finca kassandra',
#  'dragon coffee 龍咖',
#  'dragon coffee 龍咖啡',
#  'drima zede',
#  'dry',
#  'dry hull',
#  'dry in solar beds',
#  'dry mil of cocapil cooperative',
#  'dry mill',
#  'dry mill of exportcafe',
#  'dry mill of safracafe',
#  'dry mill or hulling facility',
#  'dry mill/ honey process',
#  'east java',
#  'ecc',
#  'ecc beneficio veracruz',
#  'echo coffee mill',
#  'ecom',
#  "ed&f man volcafe peru's dry mill in jaen",
#  'el borbollon',
#  'el chipoco, municipio de tlanchinol',
#  'el desmoronado',
#  'el guayabo',
#  'el injerto s.a.',
#  'el mavodo',
#  'el mirador',
#  'el morito',
#  'el olvido, zentla, veracruz',
#  'el pacayal, amatenango de la frontera, chiapas',
#  'el patalillo',
#  'el pedregal',
#  'el pino, cosautlan de carvajal',
#  'el regadito',
#  'el regalito',
#  'el romnace azul, rio verde',
#  'el tesoro',
#  'elida estate',
#  'en ahuatitlan',
#  'en chiatipan, municipio de huazalingo',
#  'en cortado beneficiado y secado por el productor',
#  'en coyula',
#  'en el plan de guadalupe',
#  'en el progreso',
#  'en santa maria temaxcalapa',
#  'en tlalnepantla',
#  'ephemera traders',
#  'exclusive coffees s.a,',
#  'exportadora atlantic sa - pp condega',
#  'exportadora café california',
#  'exportadora de cafe california',
#  'exportadora moretto s.a. de c.v.',
#  'exportcafe - ecom',
#  'f.i.e.c.h.',
#  'falcafe s.a. de c.v.',
#  'faysal abamecha processing plant at yebu town',
#  'federación nacional de cafeteros de colombia',
#  'finca aurora',
#  'finca camila',
#  'finca custepec',
#  'finca estate',
#  'finca hamburgo',
#  'finca jamaica, san gabriel mixtepec, juquila, oaxaca',
#  'finca la fortuna',
#  'finca la frontera',
#  'finca la orduña, coatepec, ver.',
#  'finca las nieves',
#  'finca los barreales',
#  'finca mata larga',
#  'finca medina',
#  'finca montegrande, jaltenango',
#  'finca quequesquez',
#  'finca santa clara, localidad de zona del bulé, san pedro pochutla oaxaca',
#  'firemariyam dry mill site',
#  'florencia',
#  'gao chun fang 高醇坊',
#  'garca armazens',
#  'genius coffee estate',
#  'good mood coffee 馨晴咖啡        ',
#  'great lakes coffee',
#  'green beans',
#  'gudmale',
#  'gumutindo',
#  'guo cun nong yuan 國村農園',
#  'guo xin ka fei 國昕咖啡',
#  'guoxing farm coffee 國姓農場咖啡        ',
#  'hacienda alto grande',
#  'hacienda la esmeralda',
#  'hand peeled',
#  'hani',
#  'heng lu coffee 橫鹿咖啡',
#  'huatusco',
#  'hulling',
#  'hulling facility',
#  'humedo: finca santo tomas pachuj y seco: beneficio palinsa',
#  'hustusco',
#  'hvc',
#  'húmedo',
#  'ibero',
#  'iliatenco, guerrero',
#  'inoi',
#  'internacional armazens gerais',
#  'ipanema coffees',
#  'ipanema comercial e exportadora sa',
#  'ixchel',
#  'ixhuatlan del café, ver.',
#  'j. hill y cia',
#  'j.j. borja nathan',
#  "jacob's estate 雅谷咖啡",
#  'jia jia coffee 佳佳咖啡莊',
#  'jing jing café 晶晶坊青山咖啡教室',
#  'juanana coffee association',
#  'ka-vulungan coffee estate',
#  'kabum trading company',
#  'kalugmanan agri development corp.',
#  'kan tou mountain coffee 崁頭山咖啡館',
#  'karatu estate',
#  'kata muduga farmers',
#  'kawacom',
#  'kawacom uganda limted',
#  'kerchanshe',
#  'kiriyama washing station',
#  'kkkld',
#  'kona pacific farmers cooperative',
#  'kongoni estate',
#  'kucofa farmers group',
#  'kyagalanyi coffee ltd',
#  "kyagalanyi coffee's namanve dry mill",
#  'la catedral del cafe',
#  'la concordia, chiapas',
#  'la conquista',
#  'la distancia',
#  'la esperanza, municipio juchique de ferrer, veracruz',
#  'la eva',
#  'la giorgia',
#  'la herradura',
#  'la laja pinillos veracruz',
#  'la majada cooperative',
#  'la tejeria',
#  'la yerba',
#  'las americas',
#  'las minas',
#  'las truchas',
#  'linda vista',
#  'llano hermoso, xochitonalco huautla, oaxaca',
#  'local made',
#  'los angeles micro-mill',
#  'los barreales, teocelo, veracruz',
#  'los pinoslos pinos',
#  'm10',
#  'mandalay coffee group',
#  'matsuzawa coffee',
#  'mazatepec, tlatlauquitepec, puebla',
#  'mbinga',
#  'mbozi coffee curing',
#  'mcomafa',
#  'mecatlán veracruz',
#  'menglian ban’an coffee processing factory',
#  'menglian county nayun town mangzhang coffee farm',
#  'menglian gao sanlin coffee factory',
#  'menglian mang pan professional cooperative',
#  'mercon coffee group cisa',
#  'metad plc',
#  'micro beneficio la cabaña-javier meza',
#  'mmm',
#  'mojiang jinggong estate speciality development co.ltd mill',
#  'mondul coffee estate',
#  'monte blanco',
#  'moplaco',
#  'mu he zi coffee 木盒子咖啡園',
#  'municipio monte cristo de guerrero, chiapasmunicipio monte cristo de guerrero',
#  'mzuzu coffee coop union',
#  'nan',
#  'neiva',
#  'ngila estate ltd',
#  'ngorogoro convenant estate',
#  'ngu shwe li coffee estate',
#  'nile highland arabica coffee farmers',
#  'nitin coffee estate',
#  'nkg coffee mills',
#  'nkg mills',
#  'nkg/ck/hc/ss/kccm',
#  'non',
#  'none',
#  'nyapea',
#  'olam',
#  'olam honduras',
#  'only dry mill',
#  'organizacion union de ejidos adolfo lopez mateos',
#  'pacho viejo',
#  'palinsa, beneficiado seco / santo tomas pachuj, beneficiado humedo',
#  'palo blanco, tlacuilotepec, puebla',
#  'pasto',
#  'peaberry',
#  'peña campana',
#  'pitalito',
#  'planta procesadora sebaco',
#  'pondokbaru, benermeriah',
#  'popayán',
#  'predio santo domingo',
#  'premium grade a',
#  'procesadora del sur sa',
#  'proceso de despulpado y lavado y zarandas para secado',
#  'productores de cafes especiales sc',
#  'productos organicos de canoas spr de rl',
#  'pt. menacom',
#  'pt. olam indonesia',
#  'pt. perkebunan nusantara xii',
#  'pt. royal pacific indah international',
#  "pu'er city longke coffee co.ltd",
#  "pu'er lingdu yunlin coffee co.ltd mill",
#  'puer jiangcheng fuwang coffee biotechnology co., ltd',
#  'puwen lvyou coffee co.,ltd',
#  'pu’er specialty coffee cupping center',
#  'r.w.j. wallace ltd',
#  'rafiki (coffee) limited',
#  'rancho bonito',
#  'rancho los laureles',
#  'rancho vigia',
#  'rio colorado',
#  'rio hamaca',
#  'rio jorco',
#  'ruchu coffee factory',
#  'sacún palma',
#  'sagana',
#  'san carlos',
#  'san diego buena vista',
#  'san fernando, chiapas',
#  'san jose del lago',
#  'san josé / neiva',
#  'san josé y el portillo',
#  'san miguel',
#  'san pedro cotzilnam, municipio de aldama, chiapas',
#  'santa adelaida',
#  'santa maria siltepec',
#  'santa maria temaxcalapa',
#  'sapan toraja',
#  'sarimakmur',
#  'sasini',
#  'sasini / kofinaf mills',
#  'sasini mills',
#  'sasini mills / thika cofee mills',
#  'scl mill',
#  'seco',
#  'seid damtew coffee export and plantation',
#  'selian coffee estate',
#  'several',
#  'several - coricafe dry mill',
#  'shah plantation',
#  'shangrilla estate ltd',
#  'sheng he shang pin coffee 聖荷上品咖啡坊',
#  'shi fang yuan 十方源',
#  'shwe yin mar',
#  'soc. coop. de caf. de ciudad barrios de r.l.',
#  'sociedad cooperativa de cafetaleros de ciudad barrios de r.l.',
#  'sogestal mumirwa',
#  'solomon worku coffee processing',
#  'song yue coffee 嵩岳咖啡',
#  'south huila',
#  'spot',
#  'sucafina colombia sas',
#  'sunshine valley estate 向陽高山咖啡',
#  'surbakti / pt.olam indonesia',
#  'taiwan hao ka 台灣好咖莊園',
#  'tapachula, chiapas',
#  'taylor winch (t) ltd',
#  'tembo coffee company ltd',
#  'tepictla y xalapa veracruz',
#  'the beneficio is designed to be ecologic',
#  'tlamatoca, hutusco, ver.',
#  'tlavictepan, huatusco',
#  'tokoffee莊園',
#  'tracon trading plc',
#  'tradicional',
#  'triladora bonanza',
#  'triladora bonanza-armenia',
#  'trilladora agricola',
#  'trilladora asia',
#  'trilladora bbi',
#  'trilladora boananza',
#  'trilladora bonanza - armenia quindio',
#  'trilladora bonanza - armenia quindioa',
#  'trilladora europa',
#  'trilladora mercedes',
#  'trilladora picaleña',
#  'tropica galliard',
#  'tsoustructive garden 鄒築園',
#  'tulla coffee farm',
#  'tutunze kahawa ltd',
#  'tuxpal',
#  'tylor winch',
#  'u.c.i.r.i.',
#  'ugacof',
#  'unex(guatemala)',
#  'union ramal santa cruz',
#  'unkown',
#  'utcam usine traitement cafe marmelade',
#  'various',
#  "various smallholders' wet mills",
#  'very famous intl.名門義理國際股份有限公司',
#  'via seca',
#  'villa talea de castro, oaxaca',
#  'weng hui ling 翁惠鈴',
#  'wet hulling',
#  'wolensu',
#  'wolthers',
#  'worka',
#  'wu kun shan coffee 吳焜山咖啡園',
#  'xicotepec de juarez',
#  'xu yuan zhang 徐源漳',
#  'yajalon, chiapas',
#  'yes',
#  'you siang coffee farmtainan, taiwan 台灣台南優香咖啡',
#  'yu jin gui 玉金櫃咖啡',
#  'yun lan coffee co. ltd mill',
#  'yunnan louis herbs r&d center',
#  'yunnan success trade co.ltd mill',
#  'zapotitlan de mendez, puebla',
#  'zaragoza itundujia, oaxaca',
#  'zaragoza, montelibano, pamal navil',
#  'zhang li hong coffee 張立宏咖啡莊園',
#  'zhou wu mountain',
#  'zhuo wu shan coffee 卓武山咖啡農場',
#  'zou zhou yuan',
#  '三彎農會',
#  '以勒咖啡',
#  '伊娜咖啡莊園',
#  '十萬咖啡（shin wan café)',
#  '南投縣埔里鎮蜈蚣里',
#  '台中市新社區崑山里',
#  '台中市新社區新社里中和街4段88號        ',
#  '向陽台灣咖啡',
#  '大鋤花間 (hoe vs. flower coffee farm)',
#  '好自在咖啡莊園',
#  '寶島咖啡',
#  '崁頭山咖啡館 (kan tou mountain coffee)',
#  '嵩岳咖啡莊園',
#  '張文進莊園',
#  '御香咖啡園 (yuxiang coffee garden)',
#  '春風咖啡',
#  '林園咖啡 lin yuan coffee',
#  '神谷山莊園',
#  '誼鎂有限公司',
#  '鄉舍咖啡 hometown coffee',
#  '雅慕伊',
#  '馨晴咖啡 good mood coffee',
#  '黑咖啡道咖啡']

# %%
a_final['Mill']=a_final['Mill'].replace(['dry','only dry mill'],'dry mill')
a_final['Mill']=a_final['Mill'].replace('dry mil of cocapil cooperative','dry mill of cocapil cooperative')
a_final['Mill']=a_final['Mill'].replace('hulling','hulling facility')
a_final['Mill']=a_final['Mill'].replace(['nan','non','none','unkown'],np.nan)
a_final['Mill']=a_final['Mill'].replace('arusha','arusha coffee mill ltd')
a_final['Mill']=a_final['Mill'].replace('bachue','bachué')
a_final['Mill']=a_final['Mill'].replace('coffee business center','coffee business center (cbc) dry mill')
a_final['Mill']=a_final['Mill'].replace('dragon coffee 龍咖','dragon coffee 龍咖啡')
a_final['Mill']=a_final['Mill'].replace('kawacom','kawacom uganda limted')
a_final['Mill']=a_final['Mill'].replace('kyagalanyi coffee ltd',"kyagalanyi coffee's namanve dry mill")
a_final['Mill']=a_final['Mill'].replace('trilladora bonanza - armenia quindioa','trilladora bonanza - armenia quindio')

# %%
# Check company col
a_final['Company']=a_final['Company'].apply(lambda s: str(s))
sorted(a_final['Company'].unique())
# Out:
# ['ac la laja sa de cv',
#  'acacia hills ltd',
#  'afca',
#  'agricola nueva granada, s.a.',
#  'agro xicotepec 2000',
#  'agrogora lta & asociación de cafés especiales del ecuador',
#  'agroindustrias unidas de mexico sa de cv',
#  'al-impex business plc',
#  'amkeni gourmet coffee group',
#  'armajaro guatemala, s. a.',
#  'asefa dukamo coffee plantetion',
#  'asociación agricola local de productores de café de huautla de jimenez        ',
#  'asociación aldea global jinotega',
#  'asociación nacional del cafe',
#  'asociación nacional del café - anacafe -',
#  'assefa belay coffee producer',
#  'atlantic specialty coffee',
#  'atlantica eportacao e importcao ltda',
#  'aung nay lin htun co., ltd',
#  'belayneh kindie',
#  'beneficiadora norteña de cafe, s. a. (bencafe)',
#  'beneficio custepec s.a. de c.v.',
#  'beneficio santa rosa',
#  'beneficio santa rosa s.a.',
#  'beneficios volcafé costa rica',
#  'blossom valley宸嶧國際',
#  'bold coast coffee',
#  'bon cafe s.a',
#  'bourbon specialty coffees',
#  'bufcoffee ltd',
#  'bugestal',
#  'bugisu cooperative union',
#  'bukonzo joint cfs',
#  'bulamburi coffee farmers association',
#  'burka coffee estate',
#  'c dorman ltd',
#  'c. dorman limited',
#  'c.i.racafe & cia s.c.a',
#  'cadexsa',
#  'cafcom',
#  'cafe colonial de tlatlauquitepec',
#  'cafe de don balbino s.c. de r.l. de c.v.',
#  'cafe de la sierra norte de puebla',
#  'cafe don balbino s.c. de r.l. de c.v.',
#  'cafe montegrande',
#  'cafe politico',
#  'cafe shunuc',
#  'cafebras comercio de cafés do brasil sa',
#  'cafebras comércio de cafes do brasil',
#  'cafeorganico.mx',
#  'cafes de naranjal s.a. de c.v',
#  'cafes finos de exportacion s de r.l.',
#  'cafes tomari sa de cv',
#  'cafessisimo compañia s.a. de c.v.',
#  'cafetal el equimite, rancho agroecológico, s.p.r. de r.l.',
#  'cafetalera del pacifico',
#  'cafetalera internacional cafinter s.a',
#  'cafetalera internacional cafinter, s.a.',
#  'cafetalera la asunción s.a. de c.v.',
#  'cafetera el grande s.a. de c.v.',
#  'café andrade, s.a. de c.v.',
#  'café do paraíso',
#  'café katsina',
#  'café monteabuelo s.a. de c.v.',
#  'café pico de loro',
#  'café san blas',
#  'carajillo café sa de cv',
#  'carcafe ltda',
#  'carmo coffees',
#  'carrillo cooperativa',
#  'ce specialty s.a.',
#  'ceca,s.a.',
#  'centro agroecológico del café a. c.',
#  'cepa centroamerica, s. a.',
#  'cesmach s.c.',
#  'cigrah',
#  'cigrah s.a de c.v',
#  'coffeas co., ltd',
#  'coffee business center ltd',
#  'coffee export',
#  'coffee exporters ltd',
#  'coffee planet corporation s.a',
#  'coffee quality institute',
#  'coffee resources inc.',
#  'coffeebythebag.com , inc.',
#  'comercial internacional exportadora, s.a.',
#  'comercializadora profesional mexicana s.a. de c.v.',
#  'comon yaj noptic s. de ss',
#  'compagnie sucrière de bel ombre ltd',
#  'compañia hondureña del café s.a. de c.v.',
#  'conscious bean coffee',
#  'consejo salvadoreño del café',
#  'cooperativa el gorrion r.l',
#  'coopetarrazú.r.l',
#  'coricafe s.a.',
#  'costco wholesale industries',
#  'cqi',
#  'dae ltd company',
#  'debesa agro industry plc',
#  'delfina farm',
#  'diamond enterprise plc',
#  'doi tung development project',
#  'dream together co. ltd',
#  'dream together inc.',
#  'ecom cca s.a.',
#  'ecom cca sa',
#  'ecomtrading',
#  'eczcafe fino s.a. de c.v.',
#  'ed&f man volcafe brasil ltda.',
#  'eduardo ambrocio',
#  'el mejor café',
#  'elfasa, s.a.',
#  'empagri s.p.r. de r.l. de c.v.',
#  'ephemera traders',
#  'essence coffee',
#  'estrategias constructivas corzu s.a. de c.v.',
#  'estrategias constructivas corzu, s.a. de c.v.',
#  'exclusive coffee - costa rica',
#  'exclusive coffees s.a.',
#  'expocaccer',
#  'exportadora atlantic s.a',
#  'exportadora café california',
#  'exportadora de cafe condor s.a',
#  'exportadora de cafés carmo de minas ltda',
#  'exportadora moretto s.a. de c.v.',
#  'exportcafe',
#  'f. gaviña & sons, inc.',
#  'fahem coffee plantation',
#  'federacion nacional de cafeteros',
#  'federación nacional de cafeteros',
#  'finca el morito',
#  'finca estate',
#  'finca hamburgo',
#  'finca kassandra',
#  'finca la estancia',
#  'finca las nieves',
#  'finca las nubes',
#  'finca los barreales',
#  'finca medina',
#  'finca santa cruz',
#  'finca santo tomas pachuj, guatemala',
#  'finca teocelo',
#  'finca triunfo verde, s.c.',
#  'garca armazens',
#  'globus coffee',
#  'great lakes coffee',
#  'green mountain coffee',
#  'greenhouse coffee china',
#  'grupo cafetalero los brujos',
#  'grupo ecom',
#  'grupo juvenil magtayani ac',
#  'grupo santab s.a. de c.v.',
#  'hacienda alto grande, llc.',
#  'hacienda la esmeralda',
#  'haia gmbh',
#  'haider abamecha coffee export',
#  'haiti coffee',
#  'hineleban foundation',
#  'ibero kenya limited',
#  'ibero tanzania',
#  'ibrahim hussien specality coffee product & exporter',
#  'indigenas de la sierra madre de motozintla san isidro labrador s. de s.s.',
#  'industrializadora de kaffee andes s.a. de c.v.',
#  'inmobiliaria e inversiones dos mil s.a.',
#  'intercof 1978 group company limited',
#  'ipanema coffees',
#  'itiah coffee llc.',
#  'japan',
#  'kabum trading company',
#  'kanematsu corporation / rnp santo tomas pachuj',
#  'karatu estate',
#  'kawacom uganda ltd',
#  'kerchanshe trading plc',
#  'keremara limited',
#  'kettles coffee roasters',
#  'klem organics coffee',
#  'kona pacific farmers cooperative',
#  'kongoni estate',
#  'kpfc',
#  'kyagalanyi coffee ltd',
#  'lanna cafe',
#  'lusso coffee lab',
#  'mae fah luang foundation',
#  'mandalay coffee group',
#  'marubeni corporation',
#  'matsuzawa coffee',
#  'mcomafa co. ltd',
#  'mercon guatemala s.a.',
#  'mercon guatemala, s. a.',
#  'mercon honduras',
#  'metad agricultural developmet plc',
#  'mlimani ngarashi',
#  'molinos de honduras',
#  'mondul coffee estate',
#  'mr.brown cafe',
#  'mviwambi coffee farm',
#  'mzuzu coffee planters coop union',
#  'nan',
#  'ncc',
#  'nestle nespresso sa',
#  'ngila estate ltd',
#  'ngorogoro convenant estate',
#  'ngu shwe li coffee estate',
#  'nile highlands arabica coffee farmers',
#  'niponn coffee trading co.,ltd.',
#  'nippon coffee trading co.,ltd',
#  'nippon coffee trading co.,ltd.',
#  'nitin coffee estate',
#  'nomura trading co., ltd.',
#  'nucoffee',
#  'nuevos mercados, s.a.',
#  'nyapea coffee farmers association',
#  'olam',
#  'olam agricola',
#  'olam honduras, s.a.',
#  'olam international ltd',
#  'olam japan',
#  'olam specialty coffee',
#  'organizaciones de productores de cafe colimense sa de cv',
#  'outspan guatemala s.a.',
#  'panamerican coffee trading',
#  'peter schoelfeld, s.a',
#  'peter schoenfeld,s.a.',
#  'prime3',
#  'prodlesur sa',
#  'productora agricola y ganadera finca la suiza, s.p.r. de r.l. de c.v.',
#  'productora rural la victoria s.p.r. de r.l.',
#  'productores e industrializadores de café orgánico la fe s.c. de r.l.',
#  'productos y servicios chilindron s.a. de c.v.',
#  'pt rajawali artha agro sejahtera (ptraas)',
#  'pt. olam indonesia',
#  'pt. royal pacific indah international',
#  'pt. sari makmur tunggal mandiri',
#  'pt. shriya artha nusantara',
#  'puer jiangcheng fuwang coffee biotechnology co., ltd',
#  'r.w.j wallace ltd',
#  'racafe & cia s.c.a',
#  'rashid moledina & co. (msa) ltd',
#  'red on tree co., ltd.',
#  'retrillas del pacifico, s. a.',
#  'richmond investment-coffee department',
#  'royal 1750 coffee',
#  'royal base corporation',
#  's&d coffee and tea',
#  's3v international importing',
#  'sangana commodities k limited',
#  'santa laura exportadora de cafe s.l.e.c. s.a.',
#  'scai',
#  'seid damtew coffee planation',
#  'selian coffee estate',
#  'sertrasa',
#  'shah plantations',
#  'shangrilla estate ltd',
#  'shwe yin mar coffee',
#  'siembras vision, s.a.',
#  'siembras vision, s.a. / ing. jorge bolaños',
#  'siembras visión, s. a.',
#  'sithar coffee co., ltd.',
#  'skn caribecafe ltda',
#  'sms plc',
#  'soc. coop. cuzcachapa de r.l.',
#  'soc. coop. de caf. de ciudad barrios de r.l.',
#  'southern viking trading company, llc',
#  'sposel s. de s.s.',
#  'star cafe ltd',
#  'sucafina colombia sas',
#  'sultana del cafe inc.',
#  'sunvirtue co., ltd.',
#  'sustainable harvest',
#  'tadesse desta import & export',
#  'taiwan coffee laboratory',
#  'tawoca',
#  'taylor winch (coffee) ltd',
#  'taylor winch (t) ltd',
#  'tcb',
#  'tcl 台灣咖啡研究室',
#  'tembo coffee company ltd',
#  'terra mia',
#  'the coffee source inc.',
#  'the specialty coffee appraisers institute of asia',
#  'thrive farmers',
#  'tokyo allied coffee roasters co.,ltd.',
#  "tony's coffee and teas, inc.",
#  'tostado sw limited',
#  'transcafe, s.a',
#  'tropica galliard',
#  'tutunze kahawa ltd',
#  'ucda',
#  'ucfa',
#  'ugacof ltd',
#  'unex (guatemala), s. a.',
#  'unex guatemala, s.a.',
#  'unicafe',
#  'union de ejidos san fernando de ri',
#  'union ramal santa cruz spr de ri',
#  'union regional de cafeticultores de la mazateca alta',
#  'unión de ejidos san fernando',
#  'upctiz zapoteca s.p.r. de r.l.',
#  'villa talea café',
#  'volcafe limited, japan',
#  'volcafe ltda.',
#  'volcafe specialty coffee',
#  'volcafe/taylorwinch tanzania ltd',
#  'volcano origin coffees',
#  'waelti schoenfeld exportadores de cafe, s.a.',
#  'waylead industrial co, ltd.',
#  'yasmin coffee plantation plc',
#  'yidnekachew debessa coffee plantation',
#  'yunnan coffee exchange',
#  'yunnan louis herbs r& d center',
#  'yunnan new century tech inc.',
#  'zeas escobar y compañía limitada',
#  '八杞莊園',
#  '宸嶧國際',
#  '宸嶧國際有限公司',
#  '王秋金']

# %%
a_final['Company']=a_final['Company'].replace(['niponn coffee trading co.,ltd.','nippon coffee trading co.,ltd'],'nippon coffee trading co.,ltd.')
a_final['Company']=a_final['Company'].replace('beneficio santa rosa','beneficio santa rosa s.a.')
a_final['Company']=a_final['Company'].replace('c. dorman limited','c dorman ltd')
a_final['Company']=a_final['Company'].replace('cafebras comércio de cafes do brasil','cafebras comercio de cafés do brasil sa')
a_final['Company']=a_final['Company'].replace('cafetalera internacional cafinter s.a','cafetalera internacional cafinter, s.a.')
a_final['Company']=a_final['Company'].replace('dream together co. ltd','dream together inc.')
a_final['Company']=a_final['Company'].replace('ecom cca sa','ecom cca s.a.')
a_final['Company']=a_final['Company'].replace('estrategias constructivas corzu s.a. de c.v.','estrategias constructivas corzu, s.a. de c.v.')
a_final['Company']=a_final['Company'].replace('federacion nacional de cafeteros','federación nacional de cafeteros')
a_final['Company']=a_final['Company'].replace('mercon guatemala s.a.','mercon guatemala, s. a.')
a_final['Company']=a_final['Company'].replace('nan',np.nan)
a_final['Company']=a_final['Company'].replace('peter schoelfeld, s.a','peter schoenfeld,s.a.')
a_final['Company']=a_final['Company'].replace('siembras vision, s.a.','siembras visión, s. a.')
a_final['Company']=a_final['Company'].replace('taylor winch (t) ltd','taylor winch (coffee) ltd')
a_final['Company']=a_final['Company'].replace('unex (guatemala), s. a.','unex guatemala, s.a.')
a_final['Company']=a_final['Company'].replace('taylor winch (t) ltd','taylor winch (coffee) ltd')

# %%
# Check region col
a_final['Region']=a_final['Region'].apply(lambda s: str(s))
sorted(a_final['Region'].unique())
# Out:
# ['52 narino (exact location: mattituy; municipal region: florida code 381',
#  'acatenango',
#  'aceh',
#  'aceh gayo',
#  'aceh tengah',
#  'ada okinawa japan',
#  'addis ababa',
#  'adolfo lopez mateos',
#  'aldea xeucalvitz, ixil region, quiche department',
#  'alta mogiana',
#  'alta paulista (sao paulo)',
#  'altotonga',
#  'amatenango de la frontera',
#  'andes mountains (imbabura, loja, zamora)',
#  'antigua',
#  'antioquia',
#  'apaneca',
#  'apaneca - ilamatepec',
#  'apaneca-ilamatepec',
#  'aricha',
#  'arusha',
#  'arusha meru',
#  'asia pacific',
#  'ataco, apaneca - ilamatepec mountain range',
#  'atitlan',
#  'atoyac de alvarez',
#  'baihe dist., tainan city 臺南市白河區',
#  'bali',
#  'bener meriah',
#  'benguet, mountain province',
#  'berastagi',
#  'blend',
#  'blida,kercha,guji,oromia',
#  'bondowoso',
#  'boquete',
#  'brazil matas de minas',
#  'brunca',
#  'bukidnon, mindanao, philppines',
#  'bulambuli eastern region',
#  'cacahuatique',
#  'cajamarca',
#  'caldas',
#  'calnali, hidalgo',
#  'campos altos - cerrado',
#  'canoas',
#  'carmo de minas',
#  'cauca',
#  'central america',
#  'central kenya',
#  'central region',
#  'central valley',
#  'cerrado',
#  'cerrado - monte carmelo - minas gerais',
#  'cerrado mineiro',
#  'chamarel (south west)',
#  'changhua baguashan 彰化市八卦山',
#  'chapadão de ferro (cerrado mineiro)',
#  'chapulhuacan, hidalgo',
#  'chiang rai',
#  'chiang rai thailand',
#  'chiangrai',
#  'chiapas',
#  'chiapas villa corzo',
#  'chiapas, jaltenango',
#  'chiayi alishan 嘉義縣阿里山鄉',
#  'chiayi fanlu嘉義縣番路鄉',
#  'chickmangalore',
#  'chilón',
#  'chocaman, veracruz',
#  'chuva, san marcos',
#  'cnra station of divo',
#  'coatepec',
#  'coatepec, coatepec',
#  'cobán alta verapaz',
#  'cofradia de suchitlan',
#  'colima',
#  'comayagua',
#  'comayagua, honduras',
#  'copan',
#  'cordoba',
#  'corillera administrative',
#  'coscomatepec',
#  'costa rica',
#  'cuarenteño',
#  'cundinamarca',
#  'dala',
#  'dalat',
#  'davao city, region 11',
#  'dehong prefecture',
#  "department d'artibonite , haiti",
#  'department of ahuachapan, municipality of apanecallamatepec mountain',
#  'dila',
#  'dipilto, nueva segovia',
#  'doe kwin, pyin oo lwin',
#  'doi chaang village, chiang rai, thialand',
#  'dolok sanggul',
#  'don duong',
#  'dondon, haiti',
#  'dongshan dist., tainan city',
#  'dongshan dist., tainan city 台南市東山區',
#  'dongshan dist., tainan city 臺南市東山區',
#  'east java',
#  'eastern',
#  'eastern highlands province',
#  'eastern uganda',
#  'eje cafetero',
#  'el balsamo, quezaltepec',
#  'el desmoronado, talpan de allende jalisco',
#  'el paraíso',
#  'el progreso',
#  'el remudadero',
#  'el tumbador, san marcos',
#  'escuitla',
#  'ethiopia',
#  'ethiopia guji uraga solomo',
#  'ethiopia sidamo guji uraga adola',
#  'ethiopia yirgacheffe',
#  'ethiopia, sidamo',
#  'fln mirador',
#  'fortín de las flores',
#  'fraijanes',
#  'gayo / takengon',
#  'gedio',
#  'gicumbi',
#  'grama valley',
#  'guatemala',
#  'guatemala huehuetenango',
#  'guatemala oriente',
#  'guayata',
#  'guinope el paraíso',
#  'guji-hambela',
#  'haiti',
#  'high mogiana',
#  'honduras copan',
#  'huabal',
#  'huanuco',
#  'huautla de jimenez',
#  'huazalingo, hidalgo',
#  'huehuetenango',
#  'huila',
#  'huila supremo',
#  'hustusco',
#  'ibiraci',
#  'ijen',
#  'ikand village',
#  'iliatenco, guerrero',
#  'ilomba vilage, mbozi',
#  'indonesia',
#  'intibuca',
#  'iwala village, mbeya rural',
#  'ixhuatlan del cafe',
#  'jalapa',
#  'jaltenango',
#  'jaltocan, hidalgo',
#  'jinotega',
#  'juchique de ferrer',
#  'juquila',
#  'kakoma',
#  'kapchorwa',
#  'kapchorwa eastern',
#  'karatu arusha',
#  'karatu ngorogoro',
#  'karatu northern',
#  'kasese',
#  'kasese, mt. rwenzori',
#  'kayanza',
#  'kefa zone, gimbo distict, at a place called woka araba, south west ethiopia.',
#  'kelem welega',
#  'kenya',
#  'kenya muranga',
#  'kiambu',
#  'kilimanjaro',
#  'kirinyaga',
#  'kona',
#  'la concordia',
#  'la concordia, chiapas',
#  'la cumbre',
#  'la paz',
#  'la plata',
#  'la reforma, san marcos',
#  'la yerba',
#  'la yerbabuena',
#  'lao p.d.r.',
#  'leye, alishan township, chiayi county',
#  'leye, alishan township, chiayi county 嘉義阿里山樂野村',
#  'limu',
#  'lington nihuta',
#  'lintong',
#  'los angeles',
#  'los cedros, francisco morazan',
#  'mahuixtlan',
#  'mainly middle of colombia',
#  'mantiqueira de minas',
#  'manyara, karatu',
#  'manzanillo',
#  'marcala',
#  'marmelade',
#  'matagalpa',
#  'matagalpa, nicaragua',
#  'matas de minas        ',
#  'mbale',
#  'mbeya',
#  'mbinga',
#  'menglian',
#  'meru',
#  'meru county',
#  'mexico',
#  'minas gerais state, cerrado region',
#  'minas gerais, br',
#  'mkuu rombo',
#  'mmm',
#  'mogiana',
#  'monte carmelo',
#  "monte carmelo's town - cerrado mineiro region",
#  'moshi',
#  'motozintla',
#  'motozintla, chiapas',
#  'mountain ali, taiwan',
#  'mountains of minas gerais',
#  'mt elgon',
#  'mt. rwenzori',
#  'mubuyu estate',
#  'mumirwa',
#  'muranga',
#  'mzuzu',
#  'nan',
#  'nantou',
#  'nanxi dist., tainan city 臺南市楠西區',
#  'naranjo',
#  'nariño',
#  'natou county',
#  'nayarit',
#  'new taipei zhonghe 新北市中和區',
#  'ngorogoro',
#  'ngozi',
#  'nkure- meru',
#  'norte',
#  'northern',
#  'nueva segovia',
#  'nuevo oriente',
#  'nyeri',
#  'oaxaca',
#  'occidental',
#  'occidente',
#  'ocosingo',
#  'ocotepeque',
#  'ohuapan, tlaltetela',
#  'oldeani , mongola',
#  'oldeani, ngorongoro',
#  'orient',
#  'oriente',
#  'oromia',
#  'oromiya',
#  'paksong,laos',
#  'pasto',
#  'penachi, cecanor',
#  'pereira',
#  'peru',
#  'petatlan',
#  'phahi',
#  'pitalito',
#  'pluma hidalogo, oaxaca',
#  'pochutla',
#  'progreso santa rosa teocelo',
#  'province of manabi, ecuador',
#  'puno',
#  'pyin oo lwin',
#  'pyinoolwin',
#  'quetzaltenango',
#  'rusizi, gikundamvura',
#  'ruvuma',
#  'ruvuma, mbinga',
#  'rwenzori',
#  'sacatepequez, guatemala',
#  'sacún palma, municipio de chilón, chiapas',
#  'san andres',
#  'san andres lempira',
#  'san bartolo tutotepec',
#  'san fernando',
#  'san ignacio',
#  'san isidro',
#  'san lucas toliman, solola',
#  'san marcos',
#  'san miguel del puerto',
#  'san pedro cotzilnam',
#  'san rafael',
#  'san ramon',
#  'santa ana',
#  'santa catarina juquila',
#  'santa maria sitepec',
#  'santa rosa',
#  'santander',
#  'santander colombia',
#  'santo domingo cacalotepec',
#  'santo reyes nopala',
#  'sapan toraja',
#  'shizingo village',
#  'sidamo',
#  'sierra alta mixe y zapoteca',
#  'sierra fraylesca, chiapas',
#  'sierra madre occidental',
#  'sierra norte yajalon, chiapas',
#  'sierra, chiapas',
#  'siguatepeque, comayagua',
#  'siltepec el triunfo',
#  'siltepec el triunfo, chiapas, mexico',
#  'sipi, mt elgon',
#  'snnp/kaffa zone,gimbowereda',
#  'snnprg; kafa; telo woreda; shada kebele',
#  'solola',
#  'south',
#  'south huila',
#  'south of minas',
#  'southern- zomba',
#  'sul de minas',
#  'sul de minas - carmo de minas',
#  'sul de minas gerais',
#  'sulawesi',
#  'sumatra',
#  'sumatra brastagi',
#  'taichung taiping 台中市太平區',
#  'taichung xinshe 台中市新社區',
#  'taiwan',
#  'taiwn zou zhou yuan',
#  'taiwu township , pingtung county 屏東縣泰武鄉',
#  'talpa de allende',
#  'tapachula',
#  'tarrazu',
#  'tarrazú',
#  'temanggung, indonesia',
#  'temaxcalapa',
#  'tenango de doria, hidalgo',
#  'tepetzingo',
#  'tepictla',
#  'test',
#  'thailand',
#  'thiotte, haiti',
#  'tlacuilotepec',
#  'tlanchinol, hidalgo',
#  'tlatlauquitepec',
#  'tolima',
#  'totutla',
#  'tres rios',
#  'turrialba',
#  'tuxtla gutierrez',
#  'vale da grama',
#  'valle central',
#  'various',
#  'veracruz',
#  'vietnam',
#  'vietnam cau dat',
#  'vietnam tutra',
#  'villa talea de castro',
#  'west and central valley',
#  'west nile',
#  'west valley',
#  'western region',
#  'xalapa',
#  'xicotepec de juarez',
#  'xishuangbanna prefecture',
#  'xochitonalco, huautla        ',
#  'yajalon',
#  'yauco region',
#  'yauk sauk, shan state',
#  'yecuatla',
#  'yirgacheffe',
#  'yunlin gukeng he bao 雲林縣古坑鄉荷苞村',
#  'yunlin 雲林縣石壁',
#  'yunnan',
#  'ywangan, shan state, myanmar',
#  'ywar ngan',
#  'ywar ngan township',
#  'zapotitlan de mendez',
#  'zaragoza itundujia',
#  'zentla',
#  'zhou wu mountain',
#  'zihuatanejo de azueta',
#  'zona de santa marta, municipio de san marcos, departamento de ocotepeque, honduras',
#  '南投國姓',
#  '古坑鄉荷包村尖山坑60號',
#  '台中和平區',
#  '台中新社',
#  '台南市東山區 (dongshan dist., tainan city)',
#  '台南市東山區( dongshan dist., tainan city)',
#  '台東太麻里',
#  '台灣',
#  '嘉義阿里山',
#  '國姓-九份二山',
#  '國姓鄉 guoshing township',
#  '苗栗三灣',
#  '苗栗泰安',
#  '雲林-石壁']

# %%
a_final['Region']=a_final['Region'].replace('apaneca - ilamatepec','apaneca-ilamatepec')
a_final['Region']=a_final['Region'].replace('chiapas','chiapas villa corzo')
a_final['Region']=a_final['Region'].replace('copan','honduras copan')
a_final['Region']=a_final['Region'].replace('matagalpa','matagalpa, nicaragua')
a_final['Region']=a_final['Region'].replace('nan',np.nan)
a_final['Region']=a_final['Region'].replace('sul de minas gerais','sul de minas')
a_final['Region']=a_final['Region'].replace('arusha','arusha meru')
a_final['Region']=a_final['Region'].replace(['chiangrai','chiang rai thailand'],'chiang rai')
a_final['Region']=a_final['Region'].replace('coatepec, coatepec','coatepec')
a_final['Region']=a_final['Region'].replace(['dongshan dist., tainan city 台南市東山區','dongshan dist., tainan city 台南市東山區'],'coatepec')
a_final['Region']=a_final['Region'].replace('leye, alishan township, chiayi county 嘉義阿里山樂野村','leye, alishan township, chiayi county')
a_final['Region']=a_final['Region'].replace('meru','meru county')
a_final['Region']=a_final['Region'].replace('motozintla','motozintla, chiapas')
a_final['Region']=a_final['Region'].replace('oromiya','oromia')
a_final['Region']=a_final['Region'].replace('pyinoolwin','pyin oo lwin')
a_final['Region']=a_final['Region'].replace('san andres','san andres lempira')
a_final['Region']=a_final['Region'].replace('santander','santander colombia')
a_final['Region']=a_final['Region'].replace('siltepec el triunfo','siltepec el triunfo, chiapas, mexico')
a_final['Region']=a_final['Region'].replace('台南市東山區 (dongshan dist., tainan city)','台南市東山區( dongshan dist., tainan city)')

# %%
# Save the cleaned file
# a_final.to_csv('arabica_final.csv',index=False)
